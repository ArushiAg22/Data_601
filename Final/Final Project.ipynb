# %% [markdown]
# # Exploratory Data Analysis on Austin TX Animal Center

# %% [markdown]
# ### Dataset Names :
# #### - Austin_Animal_Center_Intakes
# #### - Austin_Animal_Center_Outcomes
#
# ### Dataset Link : https://data.world/rebeccaclay/austin-tx-animal-center-stats

# %% [markdown]
# ## Question: What are the insights on animal shelter and which type of animals are there mostly?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.mode.chained_assignment = None

# %%
df_in = pd.read_csv('Austin_Animal_Center_Intakes.csv', parse_dates=['DateTime','MonthYear'])

df_in
# Out:
#        Animal ID     Name            DateTime MonthYear  \
# 0        A786884   *Brock 2019-01-03 16:19:00    Jan-19
# 1        A706918    Belle 2015-07-05 12:59:00    Jul-15
# 2        A724273  Runster 2016-04-14 18:43:00    Apr-16
# 3        A665644      NaN 2013-10-21 07:59:00    Oct-13
# 4        A682524      Rio 2014-06-29 10:38:00    Jun-14
# ...          ...      ...                 ...       ...
# 139576   A857608      NaN 2022-05-18 15:56:00    May-22
# 139577   A857611      NaN 2022-05-18 15:56:00    May-22
# 139578   A857640  A857640 2022-05-18 18:45:00    May-22
# 139579   A857638  A857638 2022-05-18 18:17:00    May-22
# 139580   A857639  A857639 2022-05-18 18:17:00    May-22
#
#                              Found Location Intake Type Intake Condition  \
# 0       2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1          9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2        2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                               Austin (TX)       Stray             Sick
# 4             800 Grove Blvd in Austin (TX)       Stray           Normal
# ...                                     ...         ...              ...
# 139576         914 East 37Th in Austin (TX)       Stray           Normal
# 139577         914 East 37Th in Austin (TX)       Stray           Normal
# 139578         12105 Lavinia in Austin (TX)       Stray           Normal
# 139579    1804 West Rundberg in Austin (TX)       Stray           Normal
# 139580    1804 West Rundberg in Austin (TX)       Stray           Normal
#
#        Animal Type Sex upon Intake Age upon Intake  \
# 0              Dog   Neutered Male         2 years
# 1              Dog   Spayed Female         8 years
# 2              Dog     Intact Male       11 months
# 3              Cat   Intact Female         4 weeks
# 4              Dog   Neutered Male         4 years
# ...            ...             ...             ...
# 139576         Cat     Intact Male         4 weeks
# 139577         Cat   Intact Female         4 weeks
# 139578         Cat     Intact Male        5 months
# 139579         Cat     Intact Male        3 months
# 139580         Cat     Intact Male        3 months
#
#                                         Breed        Color
# 0                                  Beagle Mix     Tricolor
# 1                    English Springer Spaniel  White/Liver
# 2                                 Basenji Mix  Sable/White
# 3                      Domestic Shorthair Mix       Calico
# 4       Doberman Pinsch/Australian Cattle Dog     Tan/Gray
# ...                                       ...          ...
# 139576                     Domestic Shorthair        Black
# 139577                     Domestic Shorthair       Tortie
# 139578                                Siamese   Seal Point
# 139579                 Domestic Shorthair Mix        Black
# 139580                   Domestic Medium Hair         Blue
#
# [139581 rows x 12 columns]

# %%
df_in.shape
# Out:
# (139581, 12)

# %%
df_out = pd.read_csv('Austin_Animal_Center_Outcomes.csv', parse_dates=['DateTime','MonthYear'])

df_out
# Out:
#        Animal ID         Name            DateTime MonthYear Date of Birth  \
# 0        A794011        Chunk 2019-05-08 18:20:00    May-19      5/2/2017
# 1        A776359        Gizmo 2018-07-18 16:02:00    Jul-18     7/12/2017
# 2        A821648          NaN 2020-08-16 11:38:00    Aug-20     8/16/2019
# 3        A720371        Moose 2016-02-13 17:59:00    Feb-16     10/8/2015
# 4        A674754          NaN 2014-03-18 11:47:00    Mar-14     3/12/2014
# ...          ...          ...                 ...       ...           ...
# 139545   A846417         Lint 2022-05-18 18:41:00    May-22     6/30/2021
# 139546   A846416         Boba 2022-05-18 18:40:00    May-22     6/30/2021
# 139547   A857302          NaN 2022-05-19 10:21:00    May-22     5/14/2021
# 139548   A857278  Barn Graham 2022-05-19 10:21:00    May-22     8/14/2009
# 139549   A857297          NaN 2022-05-19 07:35:00    May-22     5/14/2021
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0         Rto-Adopt             NaN         Cat    Neutered Male
# 1          Adoption             NaN         Dog    Neutered Male
# 2        Euthanasia             NaN       Other          Unknown
# 3          Adoption             NaN         Dog    Neutered Male
# 4          Transfer         Partner         Cat      Intact Male
# ...             ...             ...         ...              ...
# 139545     Adoption             NaN         Cat    Spayed Female
# 139546     Adoption             NaN         Cat    Spayed Female
# 139547   Euthanasia       Suffering         Cat          Unknown
# 139548   Euthanasia       Suffering         Cat    Neutered Male
# 139549   Euthanasia       Suffering       Other          Unknown
#
#        Age upon Outcome                               Breed              Color
# 0               2 years              Domestic Shorthair Mix  Brown Tabby/White
# 1                1 year             Chihuahua Shorthair Mix        White/Brown
# 2                1 year                             Raccoon               Gray
# 3              4 months  Anatol Shepherd/Labrador Retriever               Buff
# 4                6 days              Domestic Shorthair Mix       Orange Tabby
# ...                 ...                                 ...                ...
# 139545        10 months              Domestic Shorthair Mix             Tortie
# 139546        10 months              Domestic Shorthair Mix             Tortie
# 139547           1 year                Domestic Medium Hair             Orange
# 139548         12 years                Domestic Medium Hair             Orange
# 139549           1 year                             Raccoon              Brown
#
# [139550 rows x 12 columns]

# %%
df_out.shape
# Out:
# (139550, 12)

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# #### Duplicate Rows Deleted

# %%
df_in = df_in.drop_duplicates()

# %%
df_in.shape
# Out:
# (139560, 12)

# %%
df_out = df_out.drop_duplicates()

# %%
df_out.shape
# Out:
# (139532, 12)

# %% [markdown]
# #### DateTime column deleted from both dfs since it is same as MonthYear column

# %%
df_in.drop('DateTime', inplace= True, axis=1)
df_out.drop('DateTime', inplace= True, axis=1)

# %%
df_in.shape
# Out:
# (139560, 11)

# %%
df_out.shape
# Out:
# (139532, 11)

# %% [markdown]
# #### Columns with only 1 unique value is deleted

# %%
def unique_val(df):
    for this_col in df.columns:
        if(df[this_col].nunique() == 1):
            df = df.drop([this_col], axis= 1)
    return df

# %%
unique_val(df_in)
df_in.shape
# Out:
# (139560, 11)

# %%
unique_val(df_out)
df_out.shape
# Out:
# (139532, 11)

# %% [markdown]
# # Dataframes Merged

# %%
df = pd.merge(df_in, df_out, on=['Animal ID', 'Name', 'Animal Type', 'Breed', 'Color'], suffixes=('_In', '_Out'))
df
# Out:
#        Animal ID           Name MonthYear_In  \
# 0        A786884         *Brock       Jan-19
# 1        A706918          Belle       Jul-15
# 2        A724273        Runster       Apr-16
# 3        A665644            NaN       Oct-13
# 4        A682524            Rio       Jun-14
# ...          ...            ...          ...
# 179718   A857559          Teddy       May-22
# 179719   A857006  Tchalla Jones       May-22
# 179720   A810981            Abe       Dec-19
# 179721   A857603            NaN       May-22
# 179722   A830688           Mona       Mar-21
#
#                                            Found Location Intake Type  \
# 0                     2501 Magin Meadow Dr in Austin (TX)       Stray
# 1                        9409 Bluegrass Dr in Austin (TX)       Stray
# 2                      2818 Palomino Trail in Austin (TX)       Stray
# 3                                             Austin (TX)       Stray
# 4                           800 Grove Blvd in Austin (TX)       Stray
# ...                                                   ...         ...
# 179718                     2660 Gate Ridge in Austin (TX)       Stray
# 179719                  7201 Levander Loop in Austin (TX)   Abandoned
# 179720  Little Elm Park And Blue Quail Drive in Austin...       Stray
# 179721                       1515 W 5Th St in Austin (TX)    Wildlife
# 179722                   Turtle Dove Drive in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 179718           Normal         Dog   Neutered Male         4 years
# 179719           Normal         Cat   Spayed Female         4 years
# 179720           Normal         Dog     Intact Male         2 years
# 179721          Injured       Other         Unknown         2 years
# 179722           Normal         Dog   Intact Female          1 year
#
#                                         Breed                Color  \
# 0                                  Beagle Mix             Tricolor
# 1                    English Springer Spaniel          White/Liver
# 2                                 Basenji Mix          Sable/White
# 3                      Domestic Shorthair Mix               Calico
# 4       Doberman Pinsch/Australian Cattle Dog             Tan/Gray
# ...                                       ...                  ...
# 179718                          Chow Chow Mix                Black
# 179719                     Domestic Shorthair               Calico
# 179720                               Pit Bull  Black Brindle/White
# 179721                                    Bat                Brown
# 179722                           Pit Bull Mix          White/Brown
#
#        MonthYear_Out Date of Birth     Outcome Type Outcome Subtype  \
# 0             Jan-19      1/3/2017         Transfer         Partner
# 1             Jul-15      7/5/2007  Return to Owner             NaN
# 2             Apr-16     4/17/2015  Return to Owner             NaN
# 3             Oct-13     9/21/2013         Transfer         Partner
# 4             Jul-14     6/29/2010  Return to Owner             NaN
# ...              ...           ...              ...             ...
# 179718        May-22     5/18/2018  Return to Owner           Field
# 179719        May-22     5/11/2018         Adoption             NaN
# 179720        Feb-20    12/23/2017         Adoption             NaN
# 179721        May-22     5/18/2020       Euthanasia     Rabies Risk
# 179722        May-21     3/14/2020         Adoption             NaN
#
#        Sex upon Outcome Age upon Outcome
# 0         Neutered Male          2 years
# 1         Spayed Female          8 years
# 2         Neutered Male           1 year
# 3         Intact Female          4 weeks
# 4         Neutered Male          4 years
# ...                 ...              ...
# 179718    Neutered Male          4 years
# 179719    Spayed Female          4 years
# 179720    Neutered Male          2 years
# 179721          Unknown          2 years
# 179722    Spayed Female           1 year
#
# [179723 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179723 entries, 0 to 179722
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         179723 non-null  object
#  1   Name              137585 non-null  object
#  2   MonthYear_In      179723 non-null  object
#  3   Found Location    179723 non-null  object
#  4   Intake Type       179723 non-null  object
#  5   Intake Condition  179723 non-null  object
#  6   Animal Type       179723 non-null  object
#  7   Sex upon Intake   179722 non-null  object
#  8   Age upon Intake   179723 non-null  object
#  9   Breed             179723 non-null  object
#  10  Color             179723 non-null  object
#  11  MonthYear_Out     179723 non-null  object
#  12  Date of Birth     179723 non-null  object
#  13  Outcome Type      179690 non-null  object
#  14  Outcome Subtype   70090 non-null   object
#  15  Sex upon Outcome  179722 non-null  object
#  16  Age upon Outcome  179713 non-null  object
# dtypes: object(17)
# memory usage: 24.7+ MB

# %%
def age_in_months(age):
    if age == 'nan':
        return age
    
    value = age.split(' ')
   
    if value[1] == 'week' or value[1] == 'weeks':
        months = 0
        
    if value[1] == 'month' or value[1] == 'months':
        months = 1
    
    if value[1] == 'day' or value[1] == 'days':
        months = 0
    
    else: 
        months = float(value[0])

    
    return months

# %%
df['Age_Intake'] = df['Age upon Intake'].apply(age_in_months)

# %%
df['Age upon Outcome'] = df['Age upon Outcome'].astype(str)
df['Age upon Outcome'] = df['Age upon Outcome'].apply(age_in_months)

# %%
df
# Out:
#        Animal ID           Name MonthYear_In  \
# 0        A786884         *Brock       Jan-19
# 1        A706918          Belle       Jul-15
# 2        A724273        Runster       Apr-16
# 3        A665644            NaN       Oct-13
# 4        A682524            Rio       Jun-14
# ...          ...            ...          ...
# 179718   A857559          Teddy       May-22
# 179719   A857006  Tchalla Jones       May-22
# 179720   A810981            Abe       Dec-19
# 179721   A857603            NaN       May-22
# 179722   A830688           Mona       Mar-21
#
#                                            Found Location Intake Type  \
# 0                     2501 Magin Meadow Dr in Austin (TX)       Stray
# 1                        9409 Bluegrass Dr in Austin (TX)       Stray
# 2                      2818 Palomino Trail in Austin (TX)       Stray
# 3                                             Austin (TX)       Stray
# 4                           800 Grove Blvd in Austin (TX)       Stray
# ...                                                   ...         ...
# 179718                     2660 Gate Ridge in Austin (TX)       Stray
# 179719                  7201 Levander Loop in Austin (TX)   Abandoned
# 179720  Little Elm Park And Blue Quail Drive in Austin...       Stray
# 179721                       1515 W 5Th St in Austin (TX)    Wildlife
# 179722                   Turtle Dove Drive in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 179718           Normal         Dog   Neutered Male         4 years
# 179719           Normal         Cat   Spayed Female         4 years
# 179720           Normal         Dog     Intact Male         2 years
# 179721          Injured       Other         Unknown         2 years
# 179722           Normal         Dog   Intact Female          1 year
#
#                                         Breed                Color  \
# 0                                  Beagle Mix             Tricolor
# 1                    English Springer Spaniel          White/Liver
# 2                                 Basenji Mix          Sable/White
# 3                      Domestic Shorthair Mix               Calico
# 4       Doberman Pinsch/Australian Cattle Dog             Tan/Gray
# ...                                       ...                  ...
# 179718                          Chow Chow Mix                Black
# 179719                     Domestic Shorthair               Calico
# 179720                               Pit Bull  Black Brindle/White
# 179721                                    Bat                Brown
# 179722                           Pit Bull Mix          White/Brown
#
#        MonthYear_Out Date of Birth     Outcome Type Outcome Subtype  \
# 0             Jan-19      1/3/2017         Transfer         Partner
# 1             Jul-15      7/5/2007  Return to Owner             NaN
# 2             Apr-16     4/17/2015  Return to Owner             NaN
# 3             Oct-13     9/21/2013         Transfer         Partner
# 4             Jul-14     6/29/2010  Return to Owner             NaN
# ...              ...           ...              ...             ...
# 179718        May-22     5/18/2018  Return to Owner           Field
# 179719        May-22     5/11/2018         Adoption             NaN
# 179720        Feb-20    12/23/2017         Adoption             NaN
# 179721        May-22     5/18/2020       Euthanasia     Rabies Risk
# 179722        May-21     3/14/2020         Adoption             NaN
#
#        Sex upon Outcome Age upon Outcome  Age_Intake
# 0         Neutered Male              2.0         2.0
# 1         Spayed Female              8.0         8.0
# 2         Neutered Male              1.0        11.0
# 3         Intact Female              4.0         4.0
# 4         Neutered Male              4.0         4.0
# ...                 ...              ...         ...
# 179718    Neutered Male              4.0         4.0
# 179719    Spayed Female              4.0         4.0
# 179720    Neutered Male              2.0         2.0
# 179721          Unknown              2.0         2.0
# 179722    Spayed Female              1.0         1.0
#
# [179723 rows x 18 columns]

# %% [markdown]
# #### Heatmap (Visualization) of Null values

# %%
plt.subplots(figsize= (15,5))
sns.heatmap(df.isnull(), cbar= False, cmap= "viridis")
plt.show()

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# #### Checking how many values are missing in each column

# %%
df.isnull().sum().sort_values()
# Out:
# Animal ID                0
# Date of Birth            0
# MonthYear_Out            0
# Color                    0
# Breed                    0
# Age upon Outcome         0
# Age upon Intake          0
# Intake Condition         0
# Intake Type              0
# Found Location           0
# MonthYear_In             0
# Animal Type              0
# Age_Intake               0
# Sex upon Intake          1
# Sex upon Outcome         1
# Outcome Type            33
# Name                 42138
# Outcome Subtype     109633
# dtype: int64

# %% [markdown]
# #### Checking Percentage of Missing Values

# %%
for this_col in df.columns:
    prct = np.mean(df[this_col].isnull())
    print('{} - {}%'.format(this_col, round(prct*100)))
# Out:
# Animal ID - 0%
# Name - 23%
# MonthYear_In - 0%
# Found Location - 0%
# Intake Type - 0%
# Intake Condition - 0%
# Animal Type - 0%
# Sex upon Intake - 0%
# Age upon Intake - 0%
# Breed - 0%
# Color - 0%
# MonthYear_Out - 0%
# Date of Birth - 0%
# Outcome Type - 0%
# Outcome Subtype - 61%
# Sex upon Outcome - 0%
# Age upon Outcome - 0%
# Age_Intake - 0%

# %% [markdown]
# ### Filling Missing Values

# %% [markdown]
# #### Replacing the missing values in a column with "No Name"

# %%
df['Name'] = df['Name'].fillna(value= 'No Name')

# %% [markdown]
# #### Filling the missing value in a column with "Unknown"

# %%
df['Outcome Subtype'] = df['Outcome Subtype'].fillna(value= 'Unknown')

# %% [markdown]
# #### Replacing the missing value with most frequent value using mode

# %%
df['Outcome Type'] = df['Outcome Type'].fillna(df['Outcome Type'].mode().iloc[0])

# %% [markdown]
# #### Calculating Age upon outcome from DOB and MonthYear_Out

# %%
for element in (df.index):
    value= df['Age upon Outcome'][element]
    if pd.isnull(value):
        df['Age upon Outcome'][element]= df['MonthYear_Out'][element].year - df['Date of Birth'][element].year - (df['MonthYear_Out'][element].month < df['Date of Birth'][element].month)

# %% [markdown]
# #### Filling the missing value with nearest value in that column using ffill method

# %%
df['Sex upon Intake']= df['Sex upon Intake'].fillna(method='ffill')
df['Sex upon Outcome']= df['Sex upon Outcome'].fillna(method='ffill')

# %% [markdown]
# #### Heatmap (Visualization) for Null values
# ##### No Null Values found now

# %%
plt.subplots(figsize= (15,5))
sns.heatmap(df.isnull(), cbar= False, cmap= "viridis")
plt.show()

# %% [markdown]
# # Sanity Check

# %% [markdown]
# #### Sanity Check for Breed and Color

# %%
import string

alpha= string.ascii_letters
spchar= ",/ -."

allowed_char = alpha+ spchar

for element in df.index:
    for ch in df['Breed'][element]:
        if ch not in allowed_char:
            print('Breed name is not correct')
            print('Sanity check failed')
            break
print("Sanity check for Breed Names done.")
# Out:
# Sanity check for Breed Names done.

# %%
alpha= string.ascii_letters
spchar= ",/ -"

allowed_char = alpha+ spchar

for element in df.index:
    for ch in df['Color'][element]:
        if ch not in allowed_char:
            print('Color name is not correct')
            print('Sanity check failed')
            break
print("Sanity check for Color Names done.")
# Out:
# Sanity check for Color Names done.

# %% [markdown]
# #### Sanity Check for Animal Type, Sex upon Intake and Outcome, Intake type, Intake condition, Outcome Type

# %%
df['Animal Type'].value_counts()
# Out:
# Dog          113679
# Cat           57895
# Other          7462
# Bird            663
# Livestock        24
# Name: Animal Type, dtype: int64

# %%
df['Sex upon Intake'].value_counts()
# Out:
# Intact Male      53328
# Intact Female    48937
# Neutered Male    37076
# Spayed Female    29258
# Unknown          11124
# Name: Sex upon Intake, dtype: int64

# %%
df['Sex upon Outcome'].value_counts()
# Out:
# Neutered Male    70079
# Spayed Female    59270
# Intact Male      20325
# Intact Female    18925
# Unknown          11124
# Name: Sex upon Outcome, dtype: int64

# %%
df['Intake Type'].value_counts()
# Out:
# Stray                 117353
# Owner Surrender        42456
# Public Assist          13397
# Wildlife                5396
# Abandoned                837
# Euthanasia Request       284
# Name: Intake Type, dtype: int64

# %%
df['Intake Condition'].value_counts()
# Out:
# Normal        158450
# Injured         8972
# Sick            6495
# Nursing         4074
# Aged             560
# Neonatal         340
# Other            286
# Medical          207
# Feral            134
# Pregnant         119
# Behavior          76
# Space              4
# Med Attn           3
# Med Urgent         2
# Panleuk            1
# Name: Intake Condition, dtype: int64

# %%
df['Outcome Type'].value_counts()
# Out:
# Adoption           83599
# Transfer           44184
# Return to Owner    38639
# Euthanasia          9536
# Rto-Adopt           1662
# Died                1342
# Disposal             638
# Missing               99
# Relocate              24
# Name: Outcome Type, dtype: int64

# %% [markdown]
# #### Sanity Check for Age upon intake and outcome

# %%
df['Age upon Outcome'] = df['Age upon Outcome'].astype(float)

if (df['Age upon Outcome'].min() >= 0):
    print(df['Age upon Outcome'].describe(), "\n")
    print("Sanity check for Age upon Outcome done. No outliers")
else:
    print("Outliers found")
# Out:
# count    179713.000000
# mean          3.552347
# std           2.932832
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           5.000000
# max          30.000000
# Name: Age upon Outcome, dtype: float64
#
# Sanity check for Age upon Outcome done. No outliers

# %% [markdown]
# # EDA

# %%
df.dtypes
# Out:
# Animal ID            object
# Name                 object
# MonthYear_In         object
# Found Location       object
# Intake Type          object
# Intake Condition     object
# Animal Type          object
# Sex upon Intake      object
# Age upon Intake      object
# Breed                object
# Color                object
# MonthYear_Out        object
# Date of Birth        object
# Outcome Type         object
# Outcome Subtype      object
# Sex upon Outcome     object
# Age upon Outcome    float64
# Age_Intake          float64
# dtype: object

# %%
df['Intake Type'] = df['Intake Type'].astype('category')

# %%
df['Intake Condition'] = df['Intake Condition'].astype('category')

# %%
df['Animal Type'] = df['Animal Type'].astype('category')

# %%
df['Sex upon Intake'] = df['Sex upon Intake'].astype('category')

# %%
df['Sex upon Outcome'] = df['Sex upon Outcome'].astype('category')

# %%
df['Outcome Type'] = df['Outcome Type'].astype('category')

# %%
df['Name'] = df['Name'].astype('category')

# %%
df['MonthYear_In']= pd.to_datetime(df['MonthYear_In'], format="%b-%y")

# %%
df['MonthYear_Out']= pd.to_datetime(df['MonthYear_Out'], format="%b-%y")

# %%
df.dtypes
# Out:
# Animal ID                   object
# Name                      category
# MonthYear_In        datetime64[ns]
# Found Location              object
# Intake Type               category
# Intake Condition          category
# Animal Type               category
# Sex upon Intake           category
# Age upon Intake             object
# Breed                       object
# Color                       object
# MonthYear_Out       datetime64[ns]
# Date of Birth               object
# Outcome Type              category
# Outcome Subtype             object
# Sex upon Outcome          category
# Age upon Outcome           float64
# Age_Intake                 float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179723 entries, 0 to 179722
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         179723 non-null  object
#  1   Name              179723 non-null  category
#  2   MonthYear_In      179723 non-null  datetime64[ns]
#  3   Found Location    179723 non-null  object
#  4   Intake Type       179723 non-null  category
#  5   Intake Condition  179723 non-null  category
#  6   Animal Type       179723 non-null  category
#  7   Sex upon Intake   179723 non-null  category
#  8   Age upon Intake   179723 non-null  object
#  9   Breed             179723 non-null  object
#  10  Color             179723 non-null  object
#  11  MonthYear_Out     179723 non-null  datetime64[ns]
#  12  Date of Birth     179723 non-null  object
#  13  Outcome Type      179723 non-null  category
#  14  Outcome Subtype   179723 non-null  object
#  15  Sex upon Outcome  179723 non-null  category
#  16  Age upon Outcome  179713 non-null  float64
#  17  Age_Intake        179723 non-null  float64
# dtypes: category(7), datetime64[ns](2), float64(2), object(7)
# memory usage: 22.5+ MB

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Variables

# %%
animal = df['Animal Type'].value_counts()

# %%
plt.subplots(figsize= (12,7))
plt.bar(x= animal.index, height= animal.values, color='black')
plt.xticks(rotation= 90)
plt.ylabel('Count')
plt.xlabel('Animal Type')
plt.title('Animals in Shelter')
plt.show()

# %% [markdown]
# Most of the Animals in the Shelter are dogs.

# %%
intake_type = df['Intake Type'].value_counts()

# %%
plt.subplots(figsize= (12,7))
plt.bar(x= intake_type.index, height= intake_type.values)
plt.xticks(rotation= 90)
plt.ylabel('Count')
plt.xlabel('Intake Type')
plt.title('Count of Intake type')
plt.show()

# %% [markdown]
# Mostly Animals in the shelter were stray. Many animals were Owner Surrendered as well.

# %%
intake_condition = df['Intake Condition'].value_counts()

# %%
plt.subplots(figsize= (12,7))
plt.bar(x= intake_condition.index, height= intake_condition.values, color='orange')
plt.xticks(rotation= 90)
plt.ylabel('Count')
plt.xlabel('Intake Condition')
plt.title('Condition of Animals while intake')
plt.show()

# %% [markdown]
# Most of the animals taken in were in good health.

# %%
outcome_type = df['Outcome Type'].value_counts()

# %%
plt.subplots(figsize= (12,7))
plt.bar(x= outcome_type.index, height= outcome_type.values, color='green')
plt.xticks(rotation= 90)
plt.ylabel('Count')
plt.xlabel('Outcome Type')
plt.title('Outcome of Animals that were in Shelter')
plt.show()

# %% [markdown]
# Most of the animals were adopted. A few were even retuened to their owners. Maybe they were lost so owner took them back.

# %% [markdown]
# ### Continuous Variables

# %%
sns.set_style('ticks')

plot = sns.displot(data= df, x= 'Age upon Intake', kind= 'hist', height= 4, aspect= 3)
plot.set(title= "Age upon Intake")
plot.set(xlabel= "Age (months)")
plot.ax.grid(axis= 'x')

plot = sns.displot(data= df, x= 'Age upon Intake', kind= 'kde', height= 4, aspect= 3)
plot.set(title= "Age upon Intake")
plot.set(xlabel= "Age (months)")
plot.ax.grid(axis= 'x')

plot = sns.displot(data= df, x= 'Age upon Intake', kind= 'ecdf', height= 4, aspect= 3)
plot.set(title= "Age upon Intake")
plot.set(xlabel= "Age (months)")
plot.ax.grid(axis= 'x')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ACHALG~1\AppData\Local\Temp/ipykernel_17188/2890407735.py in <module>
#       6 plot.ax.grid(axis= 'x')
#       7
# ----> 8 plot = sns.displot(data= df, x= 'Age upon Intake', kind= 'kde', height= 4, aspect= 3)
#       9 plot.set(title= "Age upon Intake")
#      10 plot.set(xlabel= "Age (months)")
#
# C:\Anaconda\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2240     else:
#    2241         allowed_types = None
# -> 2242     p._attach(g, allowed_types=allowed_types, log_scale=log_scale)
#    2243
#    2244     # Check for a specification that lacks x/y data and return early
#
# C:\Anaconda\lib\site-packages\seaborn\_core.py in _attach(self, obj, allowed_types, log_scale)
#    1123                     f"{allowed_types} is required"
#    1124                 )
# -> 1125                 raise TypeError(err)
#    1126
#    1127             # Register with the matplotlib unit conversion machinery
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %% [markdown]
# Most of the animals are 1 or 2 years old when they came into shelter.
# 80% animals were less than 5 years old.

# %%
sns.set_style('ticks')

plot = sns.displot(data= df, x= 'Age upon Outcome', kind= 'hist', height= 4, aspect= 3)
plot.set(title= "Age upon Outcome")
plot.set(xlabel= "Age (years)")
plot.ax.grid(axis= 'x')

plot = sns.displot(data= df, x= 'Age upon Outcome', kind= 'kde', height= 4, aspect= 3)
plot.set(title= "Age upon Outcome")
plot.set(xlabel= "Age (years)")
plot.ax.grid(axis= 'x')

plot = sns.displot(data= df, x= 'Age upon Outcome', kind= 'ecdf', height= 4, aspect= 3)
plot.set(title= "Age upon Outcome")
plot.set(xlabel= "Age (years)")
plot.ax.grid(axis= 'x')

# %% [markdown]
# Most of the animals are 1 or 2 years old when they were taken from shelter.
# 80% animals were less than 5 years old.

# %%
df['In_Year'] = pd.DatetimeIndex(df['MonthYear_In']).year
df['In_Month'] = pd.DatetimeIndex(df['MonthYear_In']).month

in_month = df[['Animal ID', 'In_Year', 'In_Month']].groupby(['In_Year', 'In_Month']).count()
in_month.plot(kind='bar',figsize=(22,4))
plt.ylabel('Count')
plt.xticks(fontsize=14)
plt.title('Count of Animal Intakes per month')
# Out:
# Text(0.5, 1.0, 'Count of Animal Intakes per month')

# %%
df['In_Year'].value_counts()
# Out:
# 2019    25845
# 2015    24032
# 2017    23819
# 2016    23635
# 2018    23526
# 2014    22830
# 2021    14806
# 2020    11945
# 2013     4941
# 2022     4344
# Name: In_Year, dtype: int64

# %%
sns.countplot(data=df, x='In_Year')
# Out:
# <AxesSubplot:xlabel='In_Year', ylabel='count'>

# %% [markdown]
# During 2020 intakes were less maybe because of Covid. Intakes were less in 2013 and 2022 also because only few months data is available

# %%
df['In_Month'].value_counts()
# Out:
# 5     17287
# 6     16709
# 10    16618
# 7     15605
# 9     15573
# 8     15017
# 11    14592
# 4     14345
# 3     14343
# 1     13607
# 12    13601
# 2     12426
# Name: In_Month, dtype: int64

# %%
sns.countplot(data=df, x='In_Month')
# Out:
# <AxesSubplot:xlabel='In_Month', ylabel='count'>

# %% [markdown]
# Mostly animals are taken in during Summer that is May, June

# %%
df['Out_Year'] = pd.DatetimeIndex(df['MonthYear_Out']).year
df['Out_Month'] = pd.DatetimeIndex(df['MonthYear_Out']).month

in_month = df[['Animal ID', 'Out_Year', 'Out_Month']].groupby(['Out_Year', 'Out_Month']).count()
in_month.plot(kind='bar',figsize=(22,4))
plt.ylabel('Count')
plt.xticks(fontsize=14)
plt.title('Count of Animal Intakes per month')
# Out:
# Text(0.5, 1.0, 'Count of Animal Intakes per month')

# %%
df['Out_Year'].value_counts()
# Out:
# 2019    25965
# 2017    23883
# 2015    23736
# 2016    23587
# 2018    23247
# 2014    22687
# 2021    14895
# 2020    12231
# 2022     5076
# 2013     4416
# Name: Out_Year, dtype: int64

# %%
sns.countplot(data=df, x='Out_Year')
# Out:
# <AxesSubplot:xlabel='Out_Year', ylabel='count'>

# %% [markdown]
# During 2020 outtakes were less maybe because of Covid. Intakes were less in 2013 and 2022 also because only few months data is available

# %%
df['Out_Month'].value_counts()
# Out:
# 7     16474
# 10    16021
# 6     15971
# 8     15955
# 5     15449
# 12    15215
# 9     15091
# 11    14990
# 3     14320
# 1     14242
# 4     13382
# 2     12613
# Name: Out_Month, dtype: int64

# %%
sns.countplot(data=df, x='Out_Month')
# Out:
# <AxesSubplot:xlabel='Out_Month', ylabel='count'>

# %% [markdown]
# Mostly animals are taken out from shelter in from July to October

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Categorical Variables vs Categorical Variables

# %%
plot = sns.displot(df, x= "Intake Condition", y= "Outcome Type", cbar= True, aspect= 3)
plot.set(title= "Intake Condition vs Outcome Type", xlabel= "Intake Condition", ylabel= "Outcome Type")
plot.ax.tick_params(axis= 'x', labelrotation= 90)

# %% [markdown]
# Most of the animals in healthy condition were adopted

# %%
plot = sns.displot(df, x= "Outcome Type", y= "Animal Type", cbar= True, aspect= 3)
plot.set(title= "Animal Type vs Outcome Type", ylabel= "Animal Type", xlabel= "Outcome Type")
plot.ax.tick_params(axis= 'x', labelrotation= 90)

# %% [markdown]
# Mostly dogs are in the shelter so they are adopted the most as compared to cats

# %%
plot = sns.displot(df, x= "Sex upon Intake", y= "Sex upon Outcome", cbar= True, aspect= 3)
plot.set(title= "Sex upon Intake vs Sex upon Outcome", xlabel= "Sex upon Intake", ylabel= "Sex upon Outcome")
plot.ax.tick_params(axis= 'x', labelrotation= 90)

# %% [markdown]
# Sex was not change for most of the animals in the shelter

# %% [markdown]
# ### Numerical vs Numerical Variables

# %%
plt.subplots(figsize= (20,10))
plt.scatter(data= df, x= "Age upon Intake", y= "Age upon Outcome")
plt.xlabel('Age upon Intake')
plt.ylabel('Age upon Outcome')
plt.title('Age upon Intake vs Age upon Outcome')
plt.show()

# %% [markdown]
# ### Categorical vs Continuous Variables

# %% [markdown]
# Age range of the dogs is highest in the shelter

# %%
plt.subplots(figsize= (12,5))
sns.violinplot(x='Animal Type', y='Age upon Outcome', data=df)
plt.xlabel('Animal Type')
plt.ylabel('Age (in months)')
plt.title('Age of Outcome by Type')
plt.show()

# %% [markdown]
# Age range of livestock is highest who were taken out of the shelter

# %%
df_dog = df[df['Animal Type'] == 'Dog']
df_cat = df[df['Animal Type'] == 'Cat']

# %%
plot = sns.displot(df_dog, x= "Intake Condition", y= "Outcome Type", cbar= True, aspect= 3)
plot.set(title= "Intake Condition vs Outcome Type for Dogs", xlabel= "Intake Condition", ylabel= "Outcome Type")
plot.ax.tick_params(axis= 'x', labelrotation= 90)

# %% [markdown]
# Health Dogs were adopted the most in the shelter

# %%
plt.subplots(figsize= (20,7))
sns.histplot(data= df_dog, x='Intake Type', hue='Outcome Type', multiple='dodge')
plt.show()

# %% [markdown]
# Most of the stray animals were adopted or returend to owner

# %%
plot = sns.displot(df_cat, x= "Intake Condition", y= "Outcome Type", cbar= True, aspect= 3)
plot.set(title= "Intake Condition vs Outcome Type for Cats", xlabel= "Intake Condition", ylabel= "Outcome Type")
plot.ax.tick_params(axis= 'x', labelrotation= 90)

# %% [markdown]
# Healthy Cats were adopted or transffered

# %%
plt.subplots(figsize= (20,7))
sns.histplot(data= df_cat, x='Intake Type', hue='Outcome Type', multiple='dodge')
plt.show()

# %% [markdown]
# Stray cats were adopted or transffered

# %% [markdown]
# # Analysis Report:

# %% [markdown]
# Mostly Dogs are there in the shelter. Shetler took in stary animals the most during 2019. Adoption rate is good in the animal shelter. Since many dogs were returned to owner so it looks like they were lost. No harm/sex change is done to the animals in the shelter. Only few animals died in the shelter which might be because of age or illness.
